# %% [markdown]
# <a href="https://colab.research.google.com/github/Diego090700/Prog_Civil_2026_1/blob/main/Notebook_Semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADAS; ancho y alto en metros
ancho = 1
alto = 2
lm = 2 * (ancho + alto) * 3.25
av = (ancho * alto) * 2
print(lm)
print(av)
# SALIDA: sale longitud de la madera (lm) en pies y Área en metros cuadrados
print("Longitud de la madera = ",lm, "pies de longitud")
print("Area de la ventana = ",av, "Metros cuadrados")
# Out:
# 19.5
# 4
# Longitud de la madera =  19.5 piesn de longitud
# Area de la ventana =  4 Metros cuadrados
