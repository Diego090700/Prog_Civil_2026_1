# %% [markdown]
# <a href="https://colab.research.google.com/github/Diego090700/Prog_Civil_2026_1/blob/main/Dosificaci%C3%B3n_de_Mezcla_Para_Columnas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dosificación de Mezcla para Columnas**
#
# **Planteamiento**:
#
# Un ingeniero residente necesita calcular cuántos sacos de cemento se requieren para vaciar una columna de sección circular.
#
#  Se sabe que para un concreto estándar de 210 kg/cm2 (3000 psi), se consumen 9.5 sacos de cemento por cada metro cúbico de mezcla.
#
# **Requerimientos**:
#
# 1. Solicitar la altura de la columna en metros.
# 2. Solicitar el diámetro de la columna en metros.
# 3. Calcular el volumen de la columna: $$v = \pi * r^2 * h$$
# . (Sugerencia: usar 3.1416
#  o importar math.pi).
# 4. Calcular la cantidad de sacos:
# $$sacos = v * 9.5$$
#
#
# **Prueba del programa**:
#
# Para una columna de 3 metros de alto y 0.4 metros de diámetro (r=0.2 ):
#
# Volumen ≈0.377 m3.
#
# Sacos necesarios ≈3.58
#
#  (el estudiante verá aquí la importancia de los tipos decimales).

# %%
# ENTRADA: Solicitar la altura de la columna en metros.
# Solicitar el diámetro de la columna en metros.
h = float(input("Ingrese la altura de la columna en metros: "))
d = float(input("Ingrese el diámetro de la columna en metros: "))

# PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos
r = d/2
v = 3.1416 * r**2 * h
sacos = v * 9.5

# SALIDA: Imprimir el resultado
print("Volumen ≈", round(v, 3), "m3.")
print("Sacos necesarios ≈", round(sacos, 2))
# Out:
# Ingrese la altura de la columna en metros: 3
# Ingrese el diámetro de la columna en metros: 0.4
# Volumen ≈ 0.377 m3.
# Sacos necesarios ≈ 3.58

# %% [markdown]
# ```markdown
# ### Explicación del Código para el Cálculo de Sacos de Cemento
#
# Las líneas de código involucradas en el cálculo son:
#
# *   `r = d/2`:
#     *   Esta línea calcula el radio (`r`) de la columna a partir del diámetro (`d`) que fue ingresado por el usuario. El radio es la mitad del diámetro.
#
# *   `v = 3.1416 * r**2 * h`:
#     *   Aquí se calcula el volumen (`v`) de la columna. Utiliza la fórmula para el volumen de un cilindro: `V = π * r² * h`.
#     *   `3.1416` es una aproximación del valor de Pi (π).
#     *   `r**2` calcula el radio al cuadrado (r²).
#     *   `h` es la altura de la columna ingresada por el usuario.
#
# *   `sacos = v * 9.5`:
#     *   Esta línea calcula la cantidad total de sacos de cemento (`sacos`) necesarios.
#     *   Multiplica el volumen calculado de la columna (`v`) por la constante `9.5`.
#     *   La constante `9.5` representa la cantidad de sacos de cemento requeridos por cada metro cúbico de mezcla, según el planteamiento del problema.
#
# Estas líneas realizan los cálculos principales para determinar el volumen de concreto y la cantidad de cemento necesaria.
