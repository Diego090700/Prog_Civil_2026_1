# %% [markdown]
# <a href="https://colab.research.google.com/github/Diego090700/Prog_Civil_2026_1/blob/main/Primer_Notebook_Nota_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UNIVERSIDAD DE SUCRE
#
# **Facultad de Ingenieria**
#
# **Departamento de Ingenieria Civil**
#
# **DIEGO ANDRES CORREA BASILIO - 1068138928**

# %% [markdown]
# # **Aspecto Básico de la Programación con Python**
#
# Perfecto. Empecemos con un **problema sencillo de ingeniería** usando **variables y operadores en Python**.
# Trabajaremos paso a paso como en un curso de programación.
#
# ---
#
# # 1. Problema de Ingeniería
#
# Un **ingeniero agrícola** necesita calcular el **volumen de agua almacenado en un tanque rectangular** para riego.
#
# La fórmula del volumen es:
#
# [
# V = largo \times ancho \times altura
# ]
#
# donde:
#
# * (largo) = longitud del tanque (m)
# * (ancho) = ancho del tanque (m)
# * (altura) = altura del agua (m)
# * (V) = volumen del agua (m³)
#
# ---
#
# # 2. Definición del algoritmo
#
# ### Entradas (Inputs)
#
# Datos que el usuario debe ingresar:
#
# * largo del tanque
# * ancho del tanque
# * altura del agua
#
# ---
#
# ### Proceso (Processing)
#
# 1. Leer los valores de largo, ancho y altura.
# 2. Multiplicar las tres variables.
# 3. Guardar el resultado en la variable **volumen**.
#
# ---
#
# ### Salida (Output)
#
# Mostrar en pantalla:
#
# * El **volumen de agua almacenado en el tanque** en metros cúbicos.
#
# ---
#
# # 3. Pseudocódigo
#
# Antes de programar en Python, escribimos la lógica.
#
# ```
# Inicio
#
# Leer largo
# Leer ancho
# Leer altura
#
# volumen = largo * ancho * altura
#
# Mostrar "El volumen del tanque es:", volumen, "m3"
#
# Fin
# ```
#
# ---
#
# # 4. Código en Python
#
# ```python
# # -----------------------------------------
# # Programa: Cálculo del volumen de un tanque
# # Aplicación: Ingeniería agrícola / civil
# # -----------------------------------------
#
# # Entrada de datos
# largo = float(input("Ingrese el largo del tanque (m): "))
# ancho = float(input("Ingrese el ancho del tanque (m): "))
# altura = float(input("Ingrese la altura del agua (m): "))
#
# # Proceso
# volumen = largo * ancho * altura
#
# # Salida
# print("El volumen de agua almacenado es:", volumen, "m^3")
# ```
#
# ---
#
# # 5. Ejemplo de ejecución
#
# Entrada del usuario:
#
# ```
# Largo = 5 m
# Ancho = 3 m
# Altura = 2 m
# ```
#
# Resultado:
#
# ```
# El volumen de agua almacenado es: 30 m^3
# ```
#
# ---
#
# # 6. Conceptos de Python que estamos usando
#
# * **Variables:** `largo`, `ancho`, `altura`, `volumen`
# * **Tipo de dato:** `float` (números con decimales)
# * **Operador aritmético:** `*` (multiplicación)
# * **Entrada de datos:** `input()`
# * **Salida de datos:** `print()`
#
# ---
#
# ✅ **Ejercicio para ti (muy importante):**
#
# Intenta modificar el programa para calcular también:
#
# * **La capacidad del tanque en litros**
#
# Sabiendo que:
#
# [
# 1 , m^3 = 1000 , litros
# ]
#
# ---
#
# Si quieres, en el siguiente paso puedo enseñarte también:
#
# * Cómo **dibujar el diagrama de flujo del algoritmo**
# * Cómo convertir este ejercicio en un **Notebook para Google Colab**
# * O resolver un **problema real de ingeniería civil (cálculo de área de un terreno o volumen de concreto)**.

# %% [markdown]
# ### ¿Qué es Python?
#
# En términos sencillos, Python es un lenguaje de programación de **alto nivel**, lo que significa que su sintaxis es muy parecida al inglés humano, facilitando su lectura y escritura. Para un ingeniero, sus mayores ventajas son:
#
# * **Versatilidad:** Sirve tanto para un script rápido que calcula el diseño de una viga, hasta para crear una aplicación web con **Streamlit** que gestione el riego de un cultivo.
# * **Comunidad:** Existen miles de librerías creadas por otros ingenieros y científicos (como NumPy o Pandas) que ya tienen resueltas las funciones matemáticas y estadísticas que necesitarás.
#
# ---
#
# ### Tu primer acercamiento al código
#
# Antes de darte un ejemplo, quiero que pienses en la **lógica algorítmica**. Imagina que necesitas calcular el área de una parcela rectangular para un proyecto de riego.
#
# En Python, no solo buscamos que el resultado sea correcto, sino que el código sea **legible y profesional**. Aquí tienes un ejemplo básico de cómo declararíamos las variables y realizaríamos el cálculo:

# %%
# Definición de variables con nombres descriptivos
largo_metros = 50.5
ancho_metros = 20.0

# Cálculo del área (Procesamiento)
area_parcela = largo_metros * ancho_metros

# Mostrar el resultado (Salida)
print(f"El área total de la parcela es: {area_parcela} m²")

# %% [markdown]
# ### ¿Cómo lo aplicarías tú?
#
# Para que empecemos a practicar la **metodología socrática** y el pensamiento de ingeniería:
#
# Si tuvieras que calcular el **caudal** de agua que pasa por una tubería sabiendo que el caudal ($Q$) es igual a la velocidad del fluido ($v$) multiplicada por el área de la sección transversal ($A$), es decir, $Q = A \cdot v$:
#
# 1. ¿Qué nombres le pondrías a las variables para que otro ingeniero entienda tu código sin esfuerzo?
# 2. ¿Qué datos necesitarías pedirle al usuario para que el programa sea útil?
#
# **¿Te animas a escribir el pseudocódigo o la lógica de cómo resolverías este cálculo del caudal antes de pasarlo a Python?**
